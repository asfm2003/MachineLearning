# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = sns.load_dataset('Iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df['species'].replace({'setosa':1, 'versicolor':2, 'virginica':3 }, inplace = True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(df[['sepal_length','sepal_width','petal_length','petal_width']], df['species'],test_size=0.2)

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 118           7.7          2.6           6.9          2.3
# 55            5.7          2.8           4.5          1.3
# 25            5.0          3.0           1.6          0.2
# 56            6.3          3.3           4.7          1.6
# 18            5.7          3.8           1.7          0.3
# 2             4.7          3.2           1.3          0.2
# 77            6.7          3.0           5.0          1.7
# 127           6.1          3.0           4.9          1.8
# 124           6.7          3.3           5.7          2.1
# 30            4.8          3.1           1.6          0.2
# 111           6.4          2.7           5.3          1.9
# 83            6.0          2.7           5.1          1.6
# 140           6.7          3.1           5.6          2.4
# 149           5.9          3.0           5.1          1.8
# 109           7.2          3.6           6.1          2.5
# 96            5.7          2.9           4.2          1.3
# 115           6.4          3.2           5.3          2.3
# 126           6.2          2.8           4.8          1.8
# 82            5.8          2.7           3.9          1.2
# 141           6.9          3.1           5.1          2.3
# 22            4.6          3.6           1.0          0.2
# 92            5.8          2.6           4.0          1.2
# 121           5.6          2.8           4.9          2.0
# 36            5.5          3.5           1.3          0.2
# 131           7.9          3.8           6.4          2.0
# 76            6.8          2.8           4.8          1.4
# 31            5.4          3.4           1.5          0.4
# 61            5.9          3.0           4.2          1.5
# 44            5.1          3.8           1.9          0.4
# 128           6.4          2.8           5.6          2.1

# %%
lr.predict(x_test)
# Out:
# array([3, 2, 1, 2, 1, 1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 1, 2,
#        3, 1, 3, 2, 1, 2, 1, 3], dtype=int64)

# %%
lr.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
sns.pairplot(df[['sepal_length','sepal_width','petal_length','petal_width','species']],hue='species')
# Out:
# D:\MyApps\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
